# %% [markdown]
# # Tennis Action Evaluator

# %% [markdown]
# ## Introduction

# %% [markdown]
# ### Problem

# %% [markdown]
# ### Model Definition

# %% [markdown]
# #### State

# %% [markdown]
# #### Action

# %% [markdown]
# #### Rewards

# %% [markdown]
# ### Data Processing

# %% [markdown]
# #### Raw Data

# %% [markdown]
# #### Extracted data

# %% [markdown]
# ### Evaluation

# %% [markdown]
# We evaluate the model based on how well it estimates the actual probability that the agent at state $s$ performing action $a$ will win the rally.
#
# We do this by passing a list of $(s,a)$ pairs to the estimator model to get the $Q(s,a)$ indicating the probability of the agent winning. Each $(s,a)$ pair has already been marked as belonging to the winner or the loser of the rally.
#
# We deem a prediction correct in the following cases:
# 1. The $(s,a)$ pair belongs to the winner and gives a $Q(s,a) \ge 0.5$
# 2. The $(s,a)$ pair belongs to the loser and gives a $Q(s,a) \lt 0.5$
#
# The final score of the model is calculated using $\frac{\text{correct predictions}}{\text{total predictions}}$.

# %% [markdown]
# ## Approximated MC Learning

# %% [markdown]
# First, we tried a simple approximated MC learning to approximate the $Q(s,a)$ function as a baseline. This is a simple linear regression problem. We used `sklearn.linear_model.LinearRegression` to create an estimator model.
#
# Since the reward of a tennis rally is only non-zero at the end of a rally, MC learning's behavior of looking at the accumulated rewards for an entire trial might be beneficial for estimating the Q-values of tennis actions.

# %% [markdown]
# ### Training

# %% [markdown]
# Being that it is merely solving a system of linear equations, training of the estimator model is very quick for approximated MC learning.

# %%
import mc_learning as mc

mc_model = mc.train(save=False)
print(mc_model.coef_)
# Out:
# [[ 0.00046365  0.00620755  0.00934649 -0.02493163  0.0050135  -0.02148365
#   -0.00191497 -0.00411411 -0.00643848  0.0220249  -0.00568214  0.02426598
#    0.00129729 -0.00062967 -0.02203004  0.00634108 -0.00288176]]

# %% [markdown]
# ### Evaluation

# %% [markdown]
# However, accuracy is low for this method, only correctly predicting the outcome of the $Q(s,a)$ correctly 53% of the time. The $Q(s,a)$ cannot be directly represented by a linear function of the features we have defined.

# %%
from data import test_dataset
import evaluation as eval

def mc_predict(sa_pair):
    single_sample_reshape = sa_pair.reshape(1,-1)
    pred = mc_model.predict(single_sample_reshape)
    return pred

score = eval.score_model(test_dataset, mc_predict)

print(f"Linear MC Learning Accuracy: {score}")
# Out:
# Linear MC Learning Accuracy: (0.5361596009975063, 0.24950967844844793)

# %% [markdown]
# ## Deep Reinforcement Learning

# %% [markdown]
# ### MC

# %% [markdown]
# #### Training

# %%
import d_sarsa

nn_mc_model, nn_mc_report = d_sarsa.train(save=False, use_mc=True)
# Out:
# EPOCH: 1.000  train_ave_loss: 0.248  train_ave_acc: 0.562  (2.25s - 65.14s remaining) ave_loss: 0.2481544853305537 ave_acc: 0.5615109952416
# EPOCH: 2.000  train_ave_loss: 0.238  train_ave_acc: 0.612  (4.45s - 62.33s remaining) ave_loss: 0.23842012845089008 ave_acc: 0.6122052637220291
# EPOCH: 3.000  train_ave_loss: 0.230  train_ave_acc: 0.631  (6.52s - 58.66s remaining) ave_loss: 0.23001627452518583 ave_acc: 0.6313681173158942
# EPOCH: 4.000  train_ave_loss: 0.226  train_ave_acc: 0.622  (8.60s - 55.89s remaining) ave_loss: 0.22627573644966323 ave_acc: 0.6223112137194033
# EPOCH: 5.000  train_ave_loss: 0.222  train_ave_acc: 0.639  (10.72s - 53.59s remaining) ave_loss: 0.2220453667588248 ave_acc: 0.6387433616247739
# EPOCH: 6.000  train_ave_loss: 0.219  train_ave_acc: 0.635  (12.82s - 51.26s remaining) ave_loss: 0.2190375223406249 ave_acc: 0.6354637630117791
# EPOCH: 7.000  train_ave_loss: 0.215  train_ave_acc: 0.654  (14.91s - 48.98s remaining) ave_loss: 0.2145518111638572 ave_acc: 0.6542878289039173
# EPOCH: 8.000  train_ave_loss: 0.212  train_ave_acc: 0.653  (16.97s - 46.68s remaining) ave_loss: 0.21215240714137507 ave_acc: 0.6527389959217201
# EPOCH: 9.000  train_ave_loss: 0.211  train_ave_acc: 0.645  (19.03s - 44.40s remaining) ave_loss: 0.2108096750535049 ave_acc: 0.6446465588296441
# EPOCH: 10.000  train_ave_loss: 0.211  train_ave_acc: 0.655  (21.16s - 42.33s remaining) ave_loss: 0.2106717124614111 ave_acc: 0.6545205914349773
# EPOCH: 11.000  train_ave_loss: 0.207  train_ave_acc: 0.662  (23.23s - 40.12s remaining) ave_loss: 0.20733576305101345 ave_acc: 0.6623603612717734
# EPOCH: 12.000  train_ave_loss: 0.208  train_ave_acc: 0.673  (25.32s - 37.97s remaining) ave_loss: 0.2078615177335365 ave_acc: 0.6732944332660586
# EPOCH: 13.000  train_ave_loss: 0.204  train_ave_acc: 0.672  (27.35s - 35.77s remaining) ave_loss: 0.20412463468671543 ave_acc: 0.6720039556605297
# EPOCH: 14.000  train_ave_loss: 0.203  train_ave_acc: 0.679  (29.42s - 33.62s remaining) ave_loss: 0.20289292860000538 ave_acc: 0.6793621661605851
# EPOCH: 15.000  train_ave_loss: 0.203  train_ave_acc: 0.673  (31.49s - 31.49s remaining) ave_loss: 0.20325409125023225 ave_acc: 0.6734155721346569
# EPOCH: 16.000  train_ave_loss: 0.201  train_ave_acc: 0.687  (33.58s - 29.38s remaining) ave_loss: 0.20130584422291373 ave_acc: 0.687070531028972
# EPOCH: 17.000  train_ave_loss: 0.200  train_ave_acc: 0.691  (35.65s - 27.26s remaining) ave_loss: 0.2001265967182837 ave_acc: 0.6907533456842176
# EPOCH: 18.000  train_ave_loss: 0.198  train_ave_acc: 0.682  (37.74s - 25.16s remaining) ave_loss: 0.1981034276957823 ave_acc: 0.6821684501012935
# EPOCH: 19.000  train_ave_loss: 0.198  train_ave_acc: 0.692  (39.82s - 23.05s remaining) ave_loss: 0.19764653644101185 ave_acc: 0.6924413812170928
# EPOCH: 20.000  train_ave_loss: 0.200  train_ave_acc: 0.693  (41.90s - 20.95s remaining) ave_loss: 0.19962116266406876 ave_acc: 0.6933898721754257
# EPOCH: 21.000  train_ave_loss: 0.197  train_ave_acc: 0.691  (43.98s - 18.85s remaining) ave_loss: 0.1969894674385398 ave_acc: 0.6913898627516581
# EPOCH: 22.000  train_ave_loss: 0.194  train_ave_acc: 0.690  (46.07s - 16.75s remaining) ave_loss: 0.19407061731601216 ave_acc: 0.6897905621536132
# EPOCH: 23.000  train_ave_loss: 0.193  train_ave_acc: 0.708  (48.27s - 14.69s remaining) ave_loss: 0.19288403171051807 ave_acc: 0.7078877107518593
# EPOCH: 24.000  train_ave_loss: 0.194  train_ave_acc: 0.708  (50.36s - 12.59s remaining) ave_loss: 0.19394471483780318 ave_acc: 0.7075517468156898
# EPOCH: 25.000  train_ave_loss: 0.194  train_ave_acc: 0.697  (52.48s - 10.50s remaining) ave_loss: 0.19353125770945004 ave_acc: 0.6966735194599041
# EPOCH: 26.000  train_ave_loss: 0.192  train_ave_acc: 0.697  (54.56s - 8.39s remaining) ave_loss: 0.19242978065419405 ave_acc: 0.6967290472967718
# EPOCH: 27.000  train_ave_loss: 0.190  train_ave_acc: 0.706  (56.64s - 6.29s remaining) ave_loss: 0.19034064059689249 ave_acc: 0.7057276398949689
# EPOCH: 28.000  train_ave_loss: 0.187  train_ave_acc: 0.709  (58.70s - 4.19s remaining) ave_loss: 0.18654261026367588 ave_acc: 0.709122867650243
# EPOCH: 29.000  train_ave_loss: 0.187  train_ave_acc: 0.710  (60.83s - 2.10s remaining) ave_loss: 0.187075185854414 ave_acc: 0.7104909900789866
# EPOCH: 30.000  train_ave_loss: 0.189  train_ave_acc: 0.703  (62.86s - 0.00s remaining) ave_loss: 0.18917657734274515 ave_acc: 0.7025102395740083

# %%
nn_mc_report.plot('train_ave_acc')
nn_mc_report.plot('train_acc')
nn_mc_report.plot('train_ave_loss')
nn_mc_report.plot('train_loss')

# %% [markdown]
# #### Evaluation

# %%
from data import test_dataset
import evaluation as eval
import torch

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

nn_mc_model.eval()
def nn_mc_predict(sa_pair):
    single_sample_reshape = sa_pair.reshape(1,-1)
    pred = nn_mc_model(torch.from_numpy(single_sample_reshape).float().to(device))
    return pred

nn_mc_score, nn_mc_mse = eval.score_model(test_dataset, nn_mc_predict)

def nn_mc_predict_seq(sa_pair_seq):
    pred = nn_mc_model(torch.from_numpy(sa_pair_seq).float().to(device))
    return pred

nn_mc_seq_score, nn_mc_seq_mse = eval.score_model_sequential(test_dataset, nn_mc_predict_seq)

print(f"NN MC Accuracy: {nn_mc_score}")
print(f"NN MC MSE: {nn_mc_mse}")
print(f"NN MC Seq Accuracy: {nn_mc_seq_score}")
print(f"NN MC Seq MSE: {nn_mc_seq_mse}")
# Out:
# NN MC Accuracy: 0.5461346633416458
# NN MC MSE: 0.267191308606638
# NN MC Seq Accuracy: 0.600997506234414
# NN MC Seq MSE: 0.2536821389934833

# %% [markdown]
# ### SARSA

# %% [markdown]
# #### Training (Without MC Init)

# %%
import d_sarsa

nn_sarsa_model, nn_sarsa_report = d_sarsa.train(save=False, use_mc=False)
# Out:
# EPOCH: 1.000  train_ave_loss: 0.135  train_ave_acc: 0.509  (1.99s - 57.70s remaining) ave_loss: 0.13540061122445593 ave_acc: 0.5088333709512318
# EPOCH: 2.000  train_ave_loss: 0.124  train_ave_acc: 0.547  (3.94s - 55.12s remaining) ave_loss: 0.12431989556118365 ave_acc: 0.5465206448115598
# EPOCH: 3.000  train_ave_loss: 0.120  train_ave_acc: 0.548  (5.90s - 53.11s remaining) ave_loss: 0.1199886508100281 ave_acc: 0.548373199038618
# EPOCH: 4.000  train_ave_loss: 0.116  train_ave_acc: 0.557  (7.82s - 50.84s remaining) ave_loss: 0.11568048399739252 ave_acc: 0.5574368078895834
# EPOCH: 5.000  train_ave_loss: 0.114  train_ave_acc: 0.576  (9.77s - 48.86s remaining) ave_loss: 0.11383996281193848 ave_acc: 0.5758545155484933
# EPOCH: 6.000  train_ave_loss: 0.111  train_ave_acc: 0.571  (11.70s - 46.81s remaining) ave_loss: 0.11149738856271739 ave_acc: 0.5708958824694851
# EPOCH: 7.000  train_ave_loss: 0.096  train_ave_acc: 0.613  (13.63s - 44.80s remaining) ave_loss: 0.0962192170387489 ave_acc: 0.612785434412012
# EPOCH: 8.000  train_ave_loss: 0.094  train_ave_acc: 0.609  (15.55s - 42.77s remaining) ave_loss: 0.0943719629509664 ave_acc: 0.6090508795798392
# EPOCH: 9.000  train_ave_loss: 0.093  train_ave_acc: 0.609  (17.45s - 40.73s remaining) ave_loss: 0.09315771749925927 ave_acc: 0.6086244506328959
# EPOCH: 10.000  train_ave_loss: 0.092  train_ave_acc: 0.618  (19.43s - 38.87s remaining) ave_loss: 0.09166104051822528 ave_acc: 0.6175879740528879
# EPOCH: 11.000  train_ave_loss: 0.091  train_ave_acc: 0.615  (21.34s - 36.85s remaining) ave_loss: 0.09070783016979257 ave_acc: 0.6147371184494397
# EPOCH: 12.000  train_ave_loss: 0.093  train_ave_acc: 0.625  (23.28s - 34.91s remaining) ave_loss: 0.09283473400557496 ave_acc: 0.6245911951664567
# EPOCH: 13.000  train_ave_loss: 0.090  train_ave_acc: 0.630  (25.22s - 32.98s remaining) ave_loss: 0.09041737583179103 ave_acc: 0.6297155754657568
# EPOCH: 14.000  train_ave_loss: 0.089  train_ave_acc: 0.634  (27.12s - 30.99s remaining) ave_loss: 0.08891382716497805 ave_acc: 0.6335485637710566
# EPOCH: 15.000  train_ave_loss: 0.089  train_ave_acc: 0.627  (29.03s - 29.03s remaining) ave_loss: 0.08861973712117004 ave_acc: 0.6266970777445101
# EPOCH: 16.000  train_ave_loss: 0.088  train_ave_acc: 0.636  (30.93s - 27.07s remaining) ave_loss: 0.08810741494783908 ave_acc: 0.6362124413469913
# EPOCH: 17.000  train_ave_loss: 0.089  train_ave_acc: 0.643  (32.85s - 25.12s remaining) ave_loss: 0.08870071774659968 ave_acc: 0.6426299868206511
# EPOCH: 18.000  train_ave_loss: 0.087  train_ave_acc: 0.649  (34.72s - 23.15s remaining) ave_loss: 0.08749633192841258 ave_acc: 0.648519265261045
# EPOCH: 19.000  train_ave_loss: 0.086  train_ave_acc: 0.647  (36.65s - 21.22s remaining) ave_loss: 0.08556040577983752 ave_acc: 0.6468060236910154
# EPOCH: 20.000  train_ave_loss: 0.086  train_ave_acc: 0.640  (38.57s - 19.28s remaining) ave_loss: 0.08646948445763145 ave_acc: 0.6400216780170785
# EPOCH: 21.000  train_ave_loss: 0.086  train_ave_acc: 0.649  (40.49s - 17.35s remaining) ave_loss: 0.08587046921023787 ave_acc: 0.6487615770556249
# EPOCH: 22.000  train_ave_loss: 0.095  train_ave_acc: 0.637  (42.40s - 15.42s remaining) ave_loss: 0.09509017989257913 ave_acc: 0.63662885366651
# EPOCH: 23.000  train_ave_loss: 0.094  train_ave_acc: 0.657  (44.30s - 13.48s remaining) ave_loss: 0.09391369847881217 ave_acc: 0.6569651953057706
# EPOCH: 24.000  train_ave_loss: 0.090  train_ave_acc: 0.653  (46.32s - 11.58s remaining) ave_loss: 0.09031992984110834 ave_acc: 0.653380905206259
# EPOCH: 25.000  train_ave_loss: 0.091  train_ave_acc: 0.647  (48.24s - 9.65s remaining) ave_loss: 0.0912271910702094 ave_acc: 0.6467983767872431
# EPOCH: 26.000  train_ave_loss: 0.090  train_ave_acc: 0.662  (50.18s - 7.72s remaining) ave_loss: 0.09029247519448182 ave_acc: 0.6615980194365881
# EPOCH: 27.000  train_ave_loss: 0.094  train_ave_acc: 0.661  (52.12s - 5.79s remaining) ave_loss: 0.09434529875481605 ave_acc: 0.6612890678066952
# EPOCH: 28.000  train_ave_loss: 0.095  train_ave_acc: 0.673  (54.02s - 3.86s remaining) ave_loss: 0.09463479805770508 ave_acc: 0.6730129003856079
# EPOCH: 29.000  train_ave_loss: 0.093  train_ave_acc: 0.680  (55.96s - 1.93s remaining) ave_loss: 0.09348015191137267 ave_acc: 0.680301292803788
# EPOCH: 30.000  train_ave_loss: 0.093  train_ave_acc: 0.674  (57.88s - 0.00s remaining) ave_loss: 0.09309761743730377 ave_acc: 0.6741499359251608

# %%
nn_sarsa_report.plot('train_ave_acc')
nn_sarsa_report.plot('train_acc')
nn_sarsa_report.plot('train_ave_loss')
nn_sarsa_report.plot('train_loss')

# %% [markdown]
# #### Evaluation (Without MC Init)

# %%
from data import test_dataset
import evaluation as eval
import torch

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

nn_sarsa_model.eval()
def nn_predict(sa_pair):
    single_sample_reshape = sa_pair.reshape(1,-1)
    pred = nn_sarsa_model(torch.from_numpy(single_sample_reshape).float().to(device))
    return pred

nn_sarsa_score, nn_sarsa_mse = eval.score_model(test_dataset, nn_predict)

def nn_predict_seq(sa_pair_seq):
    pred = nn_sarsa_model(torch.from_numpy(sa_pair_seq).float().to(device))
    return pred

nn_sarsa_seq_score, nn_sarsa_seq_mse = eval.score_model_sequential(test_dataset, nn_predict_seq)

print(f"NN Sarsa Accuracy: {nn_sarsa_score}")
print(f"NN Sarsa MSE: {nn_sarsa_mse}")
print(f"NN Sarsa Seq Accuracy: {nn_sarsa_seq_score}")
print(f"NN Sarsa Seq MSE: {nn_sarsa_seq_mse}")
# Out:
# NN Sarsa Accuracy: 0.5461346633416458
# NN Sarsa MSE: 0.27445943031191905
# NN Sarsa Seq Accuracy: 0.5473815461346634
# NN Sarsa Seq MSE: 0.25889321218612255

# %% [markdown]
# #### Training (With MC Init)

# %%
import d_sarsa

nn_mc_state_dict = nn_mc_model.state_dict()
nn_sarsa_with_mc_model, nn_sarsa_with_mc_report = d_sarsa.train(save=False, use_mc=False, init_state_dict=nn_mc_state_dict)
# Out:
# Init state dictionary was passed. Using that to initialize model_net.
# EPOCH: 1.000  train_ave_loss: 0.091  train_ave_acc: 0.704  (2.03s - 58.93s remaining) ave_loss: 0.09069547983012066 ave_acc: 0.7035674517637699
# EPOCH: 2.000  train_ave_loss: 0.094  train_ave_acc: 0.702  (4.01s - 56.13s remaining) ave_loss: 0.09394618365886317 ave_acc: 0.7022004094359074
# EPOCH: 3.000  train_ave_loss: 0.093  train_ave_acc: 0.702  (5.92s - 53.29s remaining) ave_loss: 0.09298189132149356 ave_acc: 0.7016254695475976
# EPOCH: 4.000  train_ave_loss: 0.091  train_ave_acc: 0.683  (7.86s - 51.07s remaining) ave_loss: 0.09132999381394592 ave_acc: 0.6825160953592337
# EPOCH: 5.000  train_ave_loss: 0.090  train_ave_acc: 0.704  (9.77s - 48.86s remaining) ave_loss: 0.09046649717783167 ave_acc: 0.7040183439879231
# EPOCH: 6.000  train_ave_loss: 0.091  train_ave_acc: 0.710  (11.70s - 46.80s remaining) ave_loss: 0.09096604982074186 ave_acc: 0.709639729473906
# EPOCH: 7.000  train_ave_loss: 0.098  train_ave_acc: 0.687  (13.60s - 44.67s remaining) ave_loss: 0.09779598402771607 ave_acc: 0.6868207209163804
# EPOCH: 8.000  train_ave_loss: 0.097  train_ave_acc: 0.690  (15.56s - 42.80s remaining) ave_loss: 0.0971819180879152 ave_acc: 0.6900862656587126
# EPOCH: 9.000  train_ave_loss: 0.095  train_ave_acc: 0.703  (17.50s - 40.83s remaining) ave_loss: 0.09525149656443302 ave_acc: 0.7033627360742186
# EPOCH: 10.000  train_ave_loss: 0.095  train_ave_acc: 0.704  (19.45s - 38.90s remaining) ave_loss: 0.0953079839703037 ave_acc: 0.703697575065791
# EPOCH: 11.000  train_ave_loss: 0.095  train_ave_acc: 0.699  (21.40s - 36.96s remaining) ave_loss: 0.09469826849480638 ave_acc: 0.6986895578440513
# EPOCH: 12.000  train_ave_loss: 0.101  train_ave_acc: 0.690  (23.29s - 34.93s remaining) ave_loss: 0.10141916035557073 ave_acc: 0.6898832667733305
# EPOCH: 13.000  train_ave_loss: 0.097  train_ave_acc: 0.715  (25.21s - 32.97s remaining) ave_loss: 0.09704995192205014 ave_acc: 0.7145003456800245
# EPOCH: 14.000  train_ave_loss: 0.097  train_ave_acc: 0.699  (27.15s - 31.03s remaining) ave_loss: 0.09740425115096167 ave_acc: 0.6988170097007644
# EPOCH: 15.000  train_ave_loss: 0.098  train_ave_acc: 0.701  (29.15s - 29.15s remaining) ave_loss: 0.09781212169305582 ave_acc: 0.7005503007882834
# EPOCH: 16.000  train_ave_loss: 0.097  train_ave_acc: 0.710  (31.07s - 27.18s remaining) ave_loss: 0.09685451365854383 ave_acc: 0.7101636329543193
# EPOCH: 17.000  train_ave_loss: 0.093  train_ave_acc: 0.703  (32.98s - 25.22s remaining) ave_loss: 0.09290568053973647 ave_acc: 0.7033071706609467
# EPOCH: 18.000  train_ave_loss: 0.089  train_ave_acc: 0.725  (34.93s - 23.28s remaining) ave_loss: 0.08889425719085851 ave_acc: 0.7247805207572126
# EPOCH: 19.000  train_ave_loss: 0.090  train_ave_acc: 0.712  (36.87s - 21.34s remaining) ave_loss: 0.09034800854555257 ave_acc: 0.7117051904243278
# EPOCH: 20.000  train_ave_loss: 0.090  train_ave_acc: 0.729  (38.81s - 19.41s remaining) ave_loss: 0.089762890752394 ave_acc: 0.7288745480463337
# EPOCH: 21.000  train_ave_loss: 0.088  train_ave_acc: 0.727  (40.72s - 17.45s remaining) ave_loss: 0.08827674507280904 ave_acc: 0.7268958011554163
# EPOCH: 22.000  train_ave_loss: 0.088  train_ave_acc: 0.720  (42.65s - 15.51s remaining) ave_loss: 0.0880293445497795 ave_acc: 0.7199205313551712
# EPOCH: 23.000  train_ave_loss: 0.088  train_ave_acc: 0.723  (44.61s - 13.58s remaining) ave_loss: 0.08801038899865886 ave_acc: 0.7231836725575143
# EPOCH: 24.000  train_ave_loss: 0.086  train_ave_acc: 0.722  (46.53s - 11.63s remaining) ave_loss: 0.08625814870076358 ave_acc: 0.7216497462809455
# EPOCH: 25.000  train_ave_loss: 0.086  train_ave_acc: 0.718  (48.47s - 9.69s remaining) ave_loss: 0.08601599069629029 ave_acc: 0.7180053640261882
# EPOCH: 26.000  train_ave_loss: 0.086  train_ave_acc: 0.721  (50.39s - 7.75s remaining) ave_loss: 0.0859872081885087 ave_acc: 0.7208624095926236
# EPOCH: 27.000  train_ave_loss: 0.092  train_ave_acc: 0.722  (52.33s - 5.81s remaining) ave_loss: 0.09221731931178713 ave_acc: 0.7221575840455339
# EPOCH: 28.000  train_ave_loss: 0.091  train_ave_acc: 0.716  (54.27s - 3.88s remaining) ave_loss: 0.09113671887997822 ave_acc: 0.7157883928425549
# EPOCH: 29.000  train_ave_loss: 0.090  train_ave_acc: 0.723  (56.22s - 1.94s remaining) ave_loss: 0.08974826341710679 ave_acc: 0.7233966790780592
# EPOCH: 30.000  train_ave_loss: 0.090  train_ave_acc: 0.727  (58.14s - 0.00s remaining) ave_loss: 0.09026789584926322 ave_acc: 0.7273959542056283

# %%
nn_sarsa_with_mc_report.plot('train_ave_acc')
nn_sarsa_with_mc_report.plot('train_acc')
nn_sarsa_with_mc_report.plot('train_ave_loss')
nn_sarsa_with_mc_report.plot('train_loss')

# %% [markdown]
# #### Evaluation (With MC Init)

# %%
from data import test_dataset
import evaluation as eval
import torch

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

nn_sarsa_with_mc_model.eval()
def nn_sarsa_with_mc_predict(sa_pair):
    single_sample_reshape = sa_pair.reshape(1,-1)
    pred = nn_sarsa_with_mc_model(torch.from_numpy(single_sample_reshape).float().to(device))
    return pred

nn_sarsa_with_mc_score, nn_sarsa_with_mc_mse = eval.score_model(test_dataset, nn_sarsa_with_mc_predict)

def nn_sarsa_with_mc_predict_seq(sa_pair_seq):
    pred = nn_sarsa_with_mc_model(torch.from_numpy(sa_pair_seq).float().to(device))
    return pred

nn_sarsa_with_mc_seq_score, nn_sarsa_with_mc_seq_mse = eval.score_model_sequential(test_dataset, nn_sarsa_with_mc_predict_seq)

print(f"NN Sarsa With MC Init Accuracy: {nn_sarsa_with_mc_score}")
print(f"NN Sarsa With MC Init MSE: {nn_sarsa_with_mc_mse}")
print(f"NN Sarsa With MC Init Seq Accuracy: {nn_sarsa_with_mc_seq_score}")
print(f"NN Sarsa With MC Init Seq MSE: {nn_sarsa_with_mc_seq_mse}")
# Out:
# NN Sarsa With MC Init Accuracy: 0.5461346633416458
# NN Sarsa With MC Init MSE: 0.29722964214673725
# NN Sarsa With MC Init Seq Accuracy: 0.6059850374064838
# NN Sarsa With MC Init Seq MSE: 0.23641647453620934

# %%
import os

model_dirpath = 'experiment_models/lzy_params'
os.makedirs(model_dirpath, exist_ok=True)


torch.save(nn_mc_model.state_dict(), os.path.join(model_dirpath, 'nn_mc_model.pth'))
torch.save(nn_sarsa_model.state_dict(), os.path.join(model_dirpath, 'nn_sarsa_model.pth'))
torch.save(nn_sarsa_with_mc_model.state_dict(), os.path.join(model_dirpath, 'nn_sarsa_with_mc_model.pth'))

# %% [markdown]
# ## Conclusion

# %% [markdown]
# ### Summary

# %% [markdown]
# ### Future extensions
